# %% [markdown]
# # Visión por Computadora I - CEIA
#
# ## Trabajo Práctico 1
#
# Quiroga, Martin Gabriel
# a2412

# %% [markdown]
# ### Parte 1 (imágenes en `/white_patch`)
#
# 1. Implementar el algorimot White Patch para librarnos de las diferencias de color de iluminación.
# 2. Mostrar los resultados obtenidos y analizar las posibles fallas (si es que las hay) en el caso de Whit patch.
